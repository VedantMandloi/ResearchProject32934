# %% [markdown]
# # Attempt at fine tuning BERT with Twitter Sentiment Dataset
#
# The dataset can be found at: https://www.kaggle.com/kazanova/sentiment140
#
# **WARNING:** This dataset is too big and it will not be possible to use it here.
#
# However, The code works and if you have enough processing power go ahead!

# %%
# !nvidia-smi
# Out:
# Sun May 24 06:53:23 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !nohup pip install transformers
# Out:
# nohup: ignoring input and appending output to 'nohup.out'

# %%
import random
import numpy as np
import pandas as pd
import transformers
import time
import datetime
from tqdm import tqdm

import torch

if torch.cuda.is_available():
    device = torch.device('cuda')

# %%
MAX_LENGTH = 512
BATCH_SIZE = 8
EPOCHS = 6

# %%
df = pd.read_csv(filepath_or_buffer='/content/drive/My Drive/temp_datasets/twitter_dataset.csv', 
                 names=['target', 'id', 'date', 'flag', 'user', 'text'],
                 encoding='ISO-8859-1')

df = df.drop(labels=['id', 'date', 'flag', 'user'], axis=1)

df = df.sample(frac=1)

df.head()
# Out:
#          target                                               text
# 1163581       4  had a good cold shower  so whats up twitterwor...
# 1358751       4                        whats going twitter world?
# 1239881       4  just might be paranoid, i'm avoiding the lines...
# 557110        0  @richwells that looks really nice, esp the var...
# 1012056       4    is gonna PLAY tonight  http://plurk.com/p/vgd8z

# %%
tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-uncased',
                                                       do_lower_case=True)

# %%
def tokenize(sentences, tokenizer):
    input_ids, input_masks = [],[]
    for sentence in tqdm(sentences):
        inputs = tokenizer.encode_plus(sentence, add_special_tokens=True, max_length=MAX_LENGTH, pad_to_max_length=True, 
                                             return_attention_mask=True, return_token_type_ids=False)
        input_ids.append(inputs['input_ids'])
        input_masks.append(inputs['attention_mask'])
        
        del inputs
        
    return np.asarray(input_ids, dtype='int32'), np.asarray(input_masks, dtype='int32')

# %%
ids_1q, masks_1q = tokenize(df.text[:400000], tokenizer)
# Out:
# 100%|██████████| 400000/400000 [02:30<00:00, 2655.37it/s]

# %%
# ids_2q, masks_2q = tokenize(df.text[400000:800000], tokenizer)

# %%
# ids_3q, masks_3q = tokenize(df.text[800000:1200000], tokenizer)

# %%
# ids_4q, masks_4q = tokenize(df.text[1200000:], tokenizer)

# %%
# input_ids = np.concatenate((ids_1q, ids_2q, ids_3q, ids_4q), axis=0)

# del ids_1q, ids_2q, ids_3q, ids_4q

# %%
# input_masks = np.concatenate((masks_1q, masks_2q, masks_3q, masks_4q), axis=0)

# del masks_1q, masks_2q, masks_3q, masks_4q

# %%
input_ids = torch.tensor(ids_1q)
input_masks = torch.tensor(masks_1q)

# %%
labels = torch.tensor(df.target.values[:400000])

# %%
input_masks.shape
# Out:
# torch.Size([400000, 512])

# %%
train_dataset = torch.utils.data.TensorDataset(input_ids, input_masks, labels)

del input_ids, input_masks

train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size

train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

print(f'Train set size: {train_size}\nValid set size: {val_size}')
# Out:
# Train set size: 360000
# Valid set size: 40000

# %%
train_dataloader = torch.utils.data.DataLoader(train_dataset,
                                               sampler=torch.utils.data.RandomSampler(train_dataset),
                                               batch_size=BATCH_SIZE)

validation_dataloader = torch.utils.data.DataLoader(val_dataset,
                                             sampler=torch.utils.data.RandomSampler(val_dataset),
                                             batch_size=BATCH_SIZE)

# %%
model = transformers.BertForSequenceClassification.from_pretrained('bert-base-uncased',
                                                                   num_labels=2,
                                                                   output_attentions=False,
                                                                   output_hidden_states=False)

model.cuda()

# %%
optimizer = transformers.AdamW(model.parameters(),
                               lr=5e-5,
                               eps=1e-8)

total_steps = len(train_dataloader) * EPOCHS

scheduler = transformers.get_linear_schedule_with_warmup(optimizer,
                                                         num_warmup_steps=0,
                                                         num_training_steps=total_steps)

# %%
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

training_stats = []

total_t0 = time.time()

for epoch_i in range(0, EPOCHS):

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, EPOCHS))
    print('Training...')
    
    t0 = time.time()

    total_train_loss = 0

    model.train()

    for step, batch in enumerate(train_dataloader):
        
        if step % 50 == 0 and not step == 0:

            elapsed = format_time(time.time() - t0)
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))
            
        b_input_ids = batch[0].long().to(device)
        b_input_mask = batch[1].long().to(device)
        b_labels = batch[2].to(device)
        
        model.zero_grad()        
        
        loss, logits = model(b_input_ids, 
                             token_type_ids=None, 
                             attention_mask=b_input_mask, 
                             labels=b_labels)
        
        total_train_loss += loss.item()
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        
        optimizer.step()
        
        scheduler.step()
        
    avg_train_loss = total_train_loss / len(train_dataloader)

    training_time = format_time(time.time() - t0)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(training_time))
    
    print("")
    print("Running Validation...")
    
    t0 = time.time()
    
    model.eval()
    
    total_eval_accuracy = 0
    total_eval_loss = 0
    nb_eval_steps = 0
    
    for batch in validation_dataloader:
        
        b_input_ids = batch[0].long().to(device)
        b_input_mask = batch[1].long().to(device)
        b_labels = batch[2].to(device)
        
        with torch.no_grad():        
            
            (loss, logits) = model(b_input_ids, 
                                   token_type_ids=None, 
                                   attention_mask=b_input_mask,
                                   labels=b_labels)
       
    total_eval_loss += loss.item() 
    logits = logits.detach().cpu().numpy()
    label_ids = b_labels.to('cpu').numpy()
    
    total_eval_accuracy += flat_accuracy(logits, label_ids)
    
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))

    avg_val_loss = total_eval_loss / len(validation_dataloader)
    
    validation_time = format_time(time.time() - t0)
    
    print("  Validation Loss: {0:.2f}".format(avg_val_loss))
    print("  Validation took: {:}".format(validation_time))

    training_stats.append(
        {
            'epoch': epoch_i + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Valid. Accur.': avg_val_accuracy,
            'Training Time': training_time,
            'Validation Time': validation_time
        }
    )

print("")
print("Training complete!")

print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Out:
# ======== Epoch 1 / 6 ========
# Training...
#   Batch    50  of  45,000.    Elapsed: 0:00:37.
#   Batch   100  of  45,000.    Elapsed: 0:01:18.
#   Batch   150  of  45,000.    Elapsed: 0:01:59.
#   Batch   200  of  45,000.    Elapsed: 0:02:40.
#   Batch   250  of  45,000.    Elapsed: 0:03:21.
#   Batch   300  of  45,000.    Elapsed: 0:04:02.
#   Batch   350  of  45,000.    Elapsed: 0:04:43.
#   Batch   400  of  45,000.    Elapsed: 0:05:24.
#   Batch   450  of  45,000.    Elapsed: 0:06:05.
#   Batch   500  of  45,000.    Elapsed: 0:06:47.
#   Batch   550  of  45,000.    Elapsed: 0:07:28.
#   Batch   600  of  45,000.    Elapsed: 0:08:09.
#   Batch   650  of  45,000.    Elapsed: 0:08:50.
#   Batch   700  of  45,000.    Elapsed: 0:09:31.
#   Batch   750  of  45,000.    Elapsed: 0:10:12.
#   Batch   800  of  45,000.    Elapsed: 0:10:53.
#   Batch   850  of  45,000.    Elapsed: 0:11:34.
#   Batch   900  of  45,000.    Elapsed: 0:12:15.
#   Batch   950  of  45,000.    Elapsed: 0:12:57.
#   Batch 1,000  of  45,000.    Elapsed: 0:13:38.
#   Batch 1,050  of  45,000.    Elapsed: 0:14:19.
#   Batch 1,100  of  45,000.    Elapsed: 0:15:00.
#   Batch 1,150  of  45,000.    Elapsed: 0:15:41.
#   Batch 1,200  of  45,000.    Elapsed: 0:16:22.
#   Batch 1,250  of  45,000.    Elapsed: 0:17:03.
#   Batch 1,300  of  45,000.    Elapsed: 0:17:44.
#   Batch 1,350  of  45,000.    Elapsed: 0:18:25.
#   Batch 1,400  of  45,000.    Elapsed: 0:19:06.
#   Batch 1,450  of  45,000.    Elapsed: 0:19:47.
#   Batch 1,500  of  45,000.    Elapsed: 0:20:28.
#   Batch 1,550  of  45,000.    Elapsed: 0:21:09.
#   Batch 1,600  of  45,000.    Elapsed: 0:21:51.
#   Batch 1,650  of  45,000.    Elapsed: 0:22:32.
#   Batch 1,700  of  45,000.    Elapsed: 0:23:13.
#   Batch 1,750  of  45,000.    Elapsed: 0:23:54.
#   Batch 1,800  of  45,000.    Elapsed: 0:24:35.
#   Batch 1,850  of  45,000.    Elapsed: 0:25:16.
#   Batch 1,900  of  45,000.    Elapsed: 0:25:57.
#   Batch 1,950  of  45,000.    Elapsed: 0:26:38.
#   Batch 2,000  of  45,000.    Elapsed: 0:27:19.
#   Batch 2,050  of  45,000.    Elapsed: 0:28:00.
#   Batch 2,100  of  45,000.    Elapsed: 0:28:41.
#   Batch 2,150  of  45,000.    Elapsed: 0:29:22.
#   Batch 2,200  of  45,000.    Elapsed: 0:30:03.
#   Batch 2,250  of  45,000.    Elapsed: 0:30:44.
#   Batch 2,300  of  45,000.    Elapsed: 0:31:25.
#   Batch 2,350  of  45,000.    Elapsed: 0:32:06.
#   Batch 2,400  of  45,000.    Elapsed: 0:32:47.
#   Batch 2,450  of  45,000.    Elapsed: 0:33:28.
#   Batch 2,500  of  45,000.    Elapsed: 0:34:09.
#   Batch 2,550  of  45,000.    Elapsed: 0:34:50.
#   Batch 2,600  of  45,000.    Elapsed: 0:35:31.
#   Batch 2,650  of  45,000.    Elapsed: 0:36:12.
#   Batch 2,700  of  45,000.    Elapsed: 0:36:53.
#   Batch 2,750  of  45,000.    Elapsed: 0:37:34.
#   Batch 2,800  of  45,000.    Elapsed: 0:38:15.
#   Batch 2,850  of  45,000.    Elapsed: 0:38:56.
#   Batch 2,900  of  45,000.    Elapsed: 0:39:37.
#   Batch 2,950  of  45,000.    Elapsed: 0:40:17.
#   Batch 3,000  of  45,000.    Elapsed: 0:40:58.
#   Batch 3,050  of  45,000.    Elapsed: 0:41:39.
#   Batch 3,100  of  45,000.    Elapsed: 0:42:20.
#   Batch 3,150  of  45,000.    Elapsed: 0:43:01.
#   Batch 3,200  of  45,000.    Elapsed: 0:43:42.
#   Batch 3,250  of  45,000.    Elapsed: 0:44:23.
#   Batch 3,300  of  45,000.    Elapsed: 0:45:04.
#   Batch 3,350  of  45,000.    Elapsed: 0:45:45.
#   Batch 3,400  of  45,000.    Elapsed: 0:46:26.
#   Batch 3,450  of  45,000.    Elapsed: 0:47:07.
#   Batch 3,500  of  45,000.    Elapsed: 0:47:48.
#   Batch 3,550  of  45,000.    Elapsed: 0:48:29.
#   Batch 3,600  of  45,000.    Elapsed: 0:49:10.
#   Batch 3,650  of  45,000.    Elapsed: 0:49:51.
#   Batch 3,700  of  45,000.    Elapsed: 0:50:32.
#   Batch 3,750  of  45,000.    Elapsed: 0:51:13.
#   Batch 3,800  of  45,000.    Elapsed: 0:51:54.
#   Batch 3,850  of  45,000.    Elapsed: 0:52:35.
#   Batch 3,900  of  45,000.    Elapsed: 0:53:16.
#   Batch 3,950  of  45,000.    Elapsed: 0:53:56.
#   Batch 4,000  of  45,000.    Elapsed: 0:54:37.
#   Batch 4,050  of  45,000.    Elapsed: 0:55:18.
#   Batch 4,100  of  45,000.    Elapsed: 0:55:59.
#   Batch 4,150  of  45,000.    Elapsed: 0:56:40.
#   Batch 4,200  of  45,000.    Elapsed: 0:57:21.
#   Batch 4,250  of  45,000.    Elapsed: 0:58:02.
#   Batch 4,300  of  45,000.    Elapsed: 0:58:43.
#   Batch 4,350  of  45,000.    Elapsed: 0:59:24.
#   Batch 4,400  of  45,000.    Elapsed: 1:00:05.
#   Batch 4,450  of  45,000.    Elapsed: 1:00:46.
#   Batch 4,500  of  45,000.    Elapsed: 1:01:27.
#   Batch 4,550  of  45,000.    Elapsed: 1:02:08.
#   Batch 4,600  of  45,000.    Elapsed: 1:02:49.
#   Batch 4,650  of  45,000.    Elapsed: 1:03:30.
#   Batch 4,700  of  45,000.    Elapsed: 1:04:11.
#   Batch 4,750  of  45,000.    Elapsed: 1:04:52.
#   Batch 4,800  of  45,000.    Elapsed: 1:05:33.
#   Batch 4,850  of  45,000.    Elapsed: 1:06:14.
#   Batch 4,900  of  45,000.    Elapsed: 1:06:55.
#   Batch 4,950  of  45,000.    Elapsed: 1:07:36.
#   Batch 5,000  of  45,000.    Elapsed: 1:08:17.
#   Batch 5,050  of  45,000.    Elapsed: 1:08:57.
#   Batch 5,100  of  45,000.    Elapsed: 1:09:38.
#   Batch 5,150  of  45,000.    Elapsed: 1:10:19.
#   Batch 5,200  of  45,000.    Elapsed: 1:11:00.
#   Batch 5,250  of  45,000.    Elapsed: 1:11:41.
#   Batch 5,300  of  45,000.    Elapsed: 1:12:22.
#   Batch 5,350  of  45,000.    Elapsed: 1:13:03.
#   Batch 5,400  of  45,000.    Elapsed: 1:13:44.
#   Batch 5,450  of  45,000.    Elapsed: 1:14:25.
#   Batch 5,500  of  45,000.    Elapsed: 1:15:06.
#   Batch 5,550  of  45,000.    Elapsed: 1:15:47.
#   Batch 5,600  of  45,000.    Elapsed: 1:16:28.
#   Batch 5,650  of  45,000.    Elapsed: 1:17:09.
#   Batch 5,700  of  45,000.    Elapsed: 1:17:50.
#   Batch 5,750  of  45,000.    Elapsed: 1:18:31.
#   Batch 5,800  of  45,000.    Elapsed: 1:19:12.
#   Batch 5,850  of  45,000.    Elapsed: 1:19:53.
#   Batch 5,900  of  45,000.    Elapsed: 1:20:34.
#   Batch 5,950  of  45,000.    Elapsed: 1:21:15.
#   Batch 6,000  of  45,000.    Elapsed: 1:21:56.
#   Batch 6,050  of  45,000.    Elapsed: 1:22:37.
#   Batch 6,100  of  45,000.    Elapsed: 1:23:18.
#   Batch 6,150  of  45,000.    Elapsed: 1:23:59.
#   Batch 6,200  of  45,000.    Elapsed: 1:24:40.
#   Batch 6,250  of  45,000.    Elapsed: 1:25:21.
#   Batch 6,300  of  45,000.    Elapsed: 1:26:02.
#   Batch 6,350  of  45,000.    Elapsed: 1:26:43.
#   Batch 6,400  of  45,000.    Elapsed: 1:27:23.
#   Batch 6,450  of  45,000.    Elapsed: 1:28:04.
#   Batch 6,500  of  45,000.    Elapsed: 1:28:45.
#   Batch 6,550  of  45,000.    Elapsed: 1:29:26.
#   Batch 6,600  of  45,000.    Elapsed: 1:30:07.
#   Batch 6,650  of  45,000.    Elapsed: 1:30:48.
#   Batch 6,700  of  45,000.    Elapsed: 1:31:29.
#   Batch 6,750  of  45,000.    Elapsed: 1:32:10.
#   Batch 6,800  of  45,000.    Elapsed: 1:32:51.
#   Batch 6,850  of  45,000.    Elapsed: 1:33:32.
#   Batch 6,900  of  45,000.    Elapsed: 1:34:13.
#   Batch 6,950  of  45,000.    Elapsed: 1:34:54.
#   Batch 7,000  of  45,000.    Elapsed: 1:35:35.
#   Batch 7,050  of  45,000.    Elapsed: 1:36:16.
#   Batch 7,100  of  45,000.    Elapsed: 1:36:57.
#   Batch 7,150  of  45,000.    Elapsed: 1:37:38.
#   Batch 7,200  of  45,000.    Elapsed: 1:38:19.
#   Batch 7,250  of  45,000.    Elapsed: 1:39:00.
#   Batch 7,300  of  45,000.    Elapsed: 1:39:41.
#   Batch 7,350  of  45,000.    Elapsed: 1:40:22.
#   Batch 7,400  of  45,000.    Elapsed: 1:41:03.
#   Batch 7,450  of  45,000.    Elapsed: 1:41:44.
#   Batch 7,500  of  45,000.    Elapsed: 1:42:25.
#   Batch 7,550  of  45,000.    Elapsed: 1:43:06.
#   Batch 7,600  of  45,000.    Elapsed: 1:43:47.
#   Batch 7,650  of  45,000.    Elapsed: 1:44:28.
#   Batch 7,700  of  45,000.    Elapsed: 1:45:09.
#   Batch 7,750  of  45,000.    Elapsed: 1:45:50.
#   Batch 7,800  of  45,000.    Elapsed: 1:46:31.
#   Batch 7,850  of  45,000.    Elapsed: 1:47:12.
#   Batch 7,900  of  45,000.    Elapsed: 1:47:53.
#   Batch 7,950  of  45,000.    Elapsed: 1:48:34.
#   Batch 8,000  of  45,000.    Elapsed: 1:49:15.
#   Batch 8,050  of  45,000.    Elapsed: 1:49:56.
#   Batch 8,100  of  45,000.    Elapsed: 1:50:36.
#   Batch 8,150  of  45,000.    Elapsed: 1:51:17.
#   Batch 8,200  of  45,000.    Elapsed: 1:51:58.
#   Batch 8,250  of  45,000.    Elapsed: 1:52:39.
#   Batch 8,300  of  45,000.    Elapsed: 1:53:20.
#   Batch 8,350  of  45,000.    Elapsed: 1:54:01.
#   Batch 8,400  of  45,000.    Elapsed: 1:54:42.
#   Batch 8,450  of  45,000.    Elapsed: 1:55:23.
#   Batch 8,500  of  45,000.    Elapsed: 1:56:04.
#   Batch 8,550  of  45,000.    Elapsed: 1:56:45.
#   Batch 8,600  of  45,000.    Elapsed: 1:57:26.
#   Batch 8,650  of  45,000.    Elapsed: 1:58:07.
#   Batch 8,700  of  45,000.    Elapsed: 1:58:48.
#   Batch 8,750  of  45,000.    Elapsed: 1:59:28.
#   Batch 8,800  of  45,000.    Elapsed: 2:00:09.
#   Batch 8,850  of  45,000.    Elapsed: 2:00:50.
#   Batch 8,900  of  45,000.    Elapsed: 2:01:32.
#   Batch 8,950  of  45,000.    Elapsed: 2:02:12.
#   Batch 9,000  of  45,000.    Elapsed: 2:02:53.
#   Batch 9,050  of  45,000.    Elapsed: 2:03:34.
#   Batch 9,100  of  45,000.    Elapsed: 2:04:15.
#   Batch 9,150  of  45,000.    Elapsed: 2:04:56.
#   Batch 9,200  of  45,000.    Elapsed: 2:05:37.
#   Batch 9,250  of  45,000.    Elapsed: 2:06:18.
#   Batch 9,300  of  45,000.    Elapsed: 2:06:59.
#   Batch 9,350  of  45,000.    Elapsed: 2:07:40.
#   Batch 9,400  of  45,000.    Elapsed: 2:08:21.
#   Batch 9,450  of  45,000.    Elapsed: 2:09:02.
#   Batch 9,500  of  45,000.    Elapsed: 2:09:43.
#   Batch 9,550  of  45,000.    Elapsed: 2:10:24.
#   Batch 9,600  of  45,000.    Elapsed: 2:11:05.
#   Batch 9,650  of  45,000.    Elapsed: 2:11:46.
#   Batch 9,700  of  45,000.    Elapsed: 2:12:26.
#   Batch 9,750  of  45,000.    Elapsed: 2:13:07.
#   Batch 9,800  of  45,000.    Elapsed: 2:13:49.
#   Batch 9,850  of  45,000.    Elapsed: 2:14:30.
#   Batch 9,900  of  45,000.    Elapsed: 2:15:11.
#   Batch 9,950  of  45,000.    Elapsed: 2:15:52.
#   Batch 10,000  of  45,000.    Elapsed: 2:16:32.
#   Batch 10,050  of  45,000.    Elapsed: 2:17:14.
#   Batch 10,100  of  45,000.    Elapsed: 2:17:55.
#   Batch 10,150  of  45,000.    Elapsed: 2:18:36.
#   Batch 10,200  of  45,000.    Elapsed: 2:19:17.
#   Batch 10,250  of  45,000.    Elapsed: 2:19:58.
#   Batch 10,300  of  45,000.    Elapsed: 2:20:39.
#   Batch 10,350  of  45,000.    Elapsed: 2:21:20.
#   Batch 10,400  of  45,000.    Elapsed: 2:22:01.
#   Batch 10,450  of  45,000.    Elapsed: 2:22:42.
#   Batch 10,500  of  45,000.    Elapsed: 2:23:23.
#   Batch 10,550  of  45,000.    Elapsed: 2:24:04.
#   Batch 10,600  of  45,000.    Elapsed: 2:24:45.
#   Batch 10,650  of  45,000.    Elapsed: 2:25:26.
#   Batch 10,700  of  45,000.    Elapsed: 2:26:07.
#   Batch 10,750  of  45,000.    Elapsed: 2:26:48.
#   Batch 10,800  of  45,000.    Elapsed: 2:27:29.
#   Batch 10,850  of  45,000.    Elapsed: 2:28:10.
#   Batch 10,900  of  45,000.    Elapsed: 2:28:51.
#   Batch 10,950  of  45,000.    Elapsed: 2:29:32.
#   Batch 11,000  of  45,000.    Elapsed: 2:30:13.
#   Batch 11,050  of  45,000.    Elapsed: 2:30:54.
#   Batch 11,100  of  45,000.    Elapsed: 2:31:34.
#   Batch 11,150  of  45,000.    Elapsed: 2:32:15.
#   Batch 11,200  of  45,000.    Elapsed: 2:32:56.
#   Batch 11,250  of  45,000.    Elapsed: 2:33:37.
#   Batch 11,300  of  45,000.    Elapsed: 2:34:18.
#   Batch 11,350  of  45,000.    Elapsed: 2:34:59.
#   Batch 11,400  of  45,000.    Elapsed: 2:35:40.
#   Batch 11,450  of  45,000.    Elapsed: 2:36:21.
#   Batch 11,500  of  45,000.    Elapsed: 2:37:02.
#   Batch 11,550  of  45,000.    Elapsed: 2:37:43.
#   Batch 11,600  of  45,000.    Elapsed: 2:38:24.
#   Batch 11,650  of  45,000.    Elapsed: 2:39:05.
#   Batch 11,700  of  45,000.    Elapsed: 2:39:46.
#   Batch 11,750  of  45,000.    Elapsed: 2:40:27.
#   Batch 11,800  of  45,000.    Elapsed: 2:41:08.
#   Batch 11,850  of  45,000.    Elapsed: 2:41:49.
#   Batch 11,900  of  45,000.    Elapsed: 2:42:30.
#   Batch 11,950  of  45,000.    Elapsed: 2:43:11.
#   Batch 12,000  of  45,000.    Elapsed: 2:43:52.
#   Batch 12,050  of  45,000.    Elapsed: 2:44:33.
#   Batch 12,100  of  45,000.    Elapsed: 2:45:14.
#   Batch 12,150  of  45,000.    Elapsed: 2:45:55.
#   Batch 12,200  of  45,000.    Elapsed: 2:46:36.
#   Batch 12,250  of  45,000.    Elapsed: 2:47:17.
#   Batch 12,300  of  45,000.    Elapsed: 2:47:58.
#   Batch 12,350  of  45,000.    Elapsed: 2:48:39.
#   Batch 12,400  of  45,000.    Elapsed: 2:49:20.
#   Batch 12,450  of  45,000.    Elapsed: 2:50:01.
#   Batch 12,500  of  45,000.    Elapsed: 2:50:42.
#   Batch 12,550  of  45,000.    Elapsed: 2:51:23.
#   Batch 12,600  of  45,000.    Elapsed: 2:52:04.
#   Batch 12,650  of  45,000.    Elapsed: 2:52:45.
#   Batch 12,700  of  45,000.    Elapsed: 2:53:26.
#   Batch 12,750  of  45,000.    Elapsed: 2:54:06.
#   Batch 12,800  of  45,000.    Elapsed: 2:54:47.
#   Batch 12,850  of  45,000.    Elapsed: 2:55:28.
#   Batch 12,900  of  45,000.    Elapsed: 2:56:09.
#   Batch 12,950  of  45,000.    Elapsed: 2:56:50.
#   Batch 13,000  of  45,000.    Elapsed: 2:57:31.
#   Batch 13,050  of  45,000.    Elapsed: 2:58:12.
#   Batch 13,100  of  45,000.    Elapsed: 2:58:53.
#   Batch 13,150  of  45,000.    Elapsed: 2:59:34.
#   Batch 13,200  of  45,000.    Elapsed: 3:00:15.
#   Batch 13,250  of  45,000.    Elapsed: 3:00:56.
#   Batch 13,300  of  45,000.    Elapsed: 3:01:38.
#   Batch 13,350  of  45,000.    Elapsed: 3:02:18.
#   Batch 13,400  of  45,000.    Elapsed: 3:02:59.
#   Batch 13,450  of  45,000.    Elapsed: 3:03:40.
#   Batch 13,500  of  45,000.    Elapsed: 3:04:21.
#   Batch 13,550  of  45,000.    Elapsed: 3:05:02.
#   Batch 13,600  of  45,000.    Elapsed: 3:05:43.
#   Batch 13,650  of  45,000.    Elapsed: 3:06:24.
#   Batch 13,700  of  45,000.    Elapsed: 3:07:05.
#   Batch 13,750  of  45,000.    Elapsed: 3:07:46.
#   Batch 13,800  of  45,000.    Elapsed: 3:08:27.
#   Batch 13,850  of  45,000.    Elapsed: 3:09:08.
#   Batch 13,900  of  45,000.    Elapsed: 3:09:49.
#   Batch 13,950  of  45,000.    Elapsed: 3:10:30.
#   Batch 14,000  of  45,000.    Elapsed: 3:11:11.
#   Batch 14,050  of  45,000.    Elapsed: 3:11:52.
#   Batch 14,100  of  45,000.    Elapsed: 3:12:33.
#   Batch 14,150  of  45,000.    Elapsed: 3:13:14.
#   Batch 14,200  of  45,000.    Elapsed: 3:13:55.
#   Batch 14,250  of  45,000.    Elapsed: 3:14:36.
#   Batch 14,300  of  45,000.    Elapsed: 3:15:17.
#   Batch 14,350  of  45,000.    Elapsed: 3:15:58.
#   Batch 14,400  of  45,000.    Elapsed: 3:16:39.
#   Batch 14,450  of  45,000.    Elapsed: 3:17:20.
#   Batch 14,500  of  45,000.    Elapsed: 3:18:02.
#   Batch 14,550  of  45,000.    Elapsed: 3:18:43.
#   Batch 14,600  of  45,000.    Elapsed: 3:19:24.
#   Batch 14,650  of  45,000.    Elapsed: 3:20:04.
#   Batch 14,700  of  45,000.    Elapsed: 3:20:45.
#   Batch 14,750  of  45,000.    Elapsed: 3:21:26.
#   Batch 14,800  of  45,000.    Elapsed: 3:22:07.
#   Batch 14,850  of  45,000.    Elapsed: 3:22:48.
#   Batch 14,900  of  45,000.    Elapsed: 3:23:29.
#   Batch 14,950  of  45,000.    Elapsed: 3:24:10.
#   Batch 15,000  of  45,000.    Elapsed: 3:24:51.
#   Batch 15,050  of  45,000.    Elapsed: 3:25:32.
#   Batch 15,100  of  45,000.    Elapsed: 3:26:13.
#   Batch 15,150  of  45,000.    Elapsed: 3:26:54.
#   Batch 15,200  of  45,000.    Elapsed: 3:27:35.
#   Batch 15,250  of  45,000.    Elapsed: 3:28:16.
#   Batch 15,300  of  45,000.    Elapsed: 3:28:57.
#   Batch 15,350  of  45,000.    Elapsed: 3:29:38.
#   Batch 15,400  of  45,000.    Elapsed: 3:30:19.
#   Batch 15,450  of  45,000.    Elapsed: 3:31:00.
#   Batch 15,500  of  45,000.    Elapsed: 3:31:41.
#   Batch 15,550  of  45,000.    Elapsed: 3:32:22.
#   Batch 15,600  of  45,000.    Elapsed: 3:33:03.
#   Batch 15,650  of  45,000.    Elapsed: 3:33:44.
#   Batch 15,700  of  45,000.    Elapsed: 3:34:25.
#   Batch 15,750  of  45,000.    Elapsed: 3:35:06.
#   Batch 15,800  of  45,000.    Elapsed: 3:35:47.
#   Batch 15,850  of  45,000.    Elapsed: 3:36:28.
#   Batch 15,900  of  45,000.    Elapsed: 3:37:09.
#   Batch 15,950  of  45,000.    Elapsed: 3:37:50.
#   Batch 16,000  of  45,000.    Elapsed: 3:38:31.
#   Batch 16,050  of  45,000.    Elapsed: 3:39:12.
#   Batch 16,100  of  45,000.    Elapsed: 3:39:53.
#   Batch 16,150  of  45,000.    Elapsed: 3:40:34.
#   Batch 16,200  of  45,000.    Elapsed: 3:41:15.
#   Batch 16,250  of  45,000.    Elapsed: 3:41:56.
#   Batch 16,300  of  45,000.    Elapsed: 3:42:37.
#   Batch 16,350  of  45,000.    Elapsed: 3:43:18.
#   Batch 16,400  of  45,000.    Elapsed: 3:43:59.
#   Batch 16,450  of  45,000.    Elapsed: 3:44:40.
#   Batch 16,500  of  45,000.    Elapsed: 3:45:21.
#   Batch 16,550  of  45,000.    Elapsed: 3:46:02.
#   Batch 16,600  of  45,000.    Elapsed: 3:46:43.
#   Batch 16,650  of  45,000.    Elapsed: 3:47:24.
#   Batch 16,700  of  45,000.    Elapsed: 3:48:05.
#   Batch 16,750  of  45,000.    Elapsed: 3:48:46.
#   Batch 16,800  of  45,000.    Elapsed: 3:49:27.
#   Batch 16,850  of  45,000.    Elapsed: 3:50:08.
#   Batch 16,900  of  45,000.    Elapsed: 3:50:49.
#   Batch 16,950  of  45,000.    Elapsed: 3:51:30.
#   Batch 17,000  of  45,000.    Elapsed: 3:52:11.
#   Batch 17,050  of  45,000.    Elapsed: 3:52:52.
#   Batch 17,100  of  45,000.    Elapsed: 3:53:32.
#   Batch 17,150  of  45,000.    Elapsed: 3:54:13.
#   Batch 17,200  of  45,000.    Elapsed: 3:54:55.
#   Batch 17,250  of  45,000.    Elapsed: 3:55:36.
#   Batch 17,300  of  45,000.    Elapsed: 3:56:17.
#   Batch 17,350  of  45,000.    Elapsed: 3:56:57.
#   Batch 17,400  of  45,000.    Elapsed: 3:57:38.
#   Batch 17,450  of  45,000.    Elapsed: 3:58:19.
#   Batch 17,500  of  45,000.    Elapsed: 3:59:00.
#   Batch 17,550  of  45,000.    Elapsed: 3:59:42.
#   Batch 17,600  of  45,000.    Elapsed: 4:00:23.
#   Batch 17,650  of  45,000.    Elapsed: 4:01:04.
#   Batch 17,700  of  45,000.    Elapsed: 4:01:45.
#   Batch 17,750  of  45,000.    Elapsed: 4:02:26.
#   Batch 17,800  of  45,000.    Elapsed: 4:03:06.
#   Batch 17,850  of  45,000.    Elapsed: 4:03:47.
#   Batch 17,900  of  45,000.    Elapsed: 4:04:28.
#   Batch 17,950  of  45,000.    Elapsed: 4:05:09.
#   Batch 18,000  of  45,000.    Elapsed: 4:05:50.
#   Batch 18,050  of  45,000.    Elapsed: 4:06:31.
#   Batch 18,100  of  45,000.    Elapsed: 4:07:12.
#   Batch 18,150  of  45,000.    Elapsed: 4:07:53.
#   Batch 18,200  of  45,000.    Elapsed: 4:08:34.
#   Batch 18,250  of  45,000.    Elapsed: 4:09:15.
#   Batch 18,300  of  45,000.    Elapsed: 4:09:56.
#   Batch 18,350  of  45,000.    Elapsed: 4:10:37.
#   Batch 18,400  of  45,000.    Elapsed: 4:11:18.
#   Batch 18,450  of  45,000.    Elapsed: 4:11:59.
#   Batch 18,500  of  45,000.    Elapsed: 4:12:40.
#   Batch 18,550  of  45,000.    Elapsed: 4:13:21.
#   Batch 18,600  of  45,000.    Elapsed: 4:14:02.
#   Batch 18,650  of  45,000.    Elapsed: 4:14:43.
#   Batch 18,700  of  45,000.    Elapsed: 4:15:24.
#   Batch 18,750  of  45,000.    Elapsed: 4:16:05.
#   Batch 18,800  of  45,000.    Elapsed: 4:16:46.
#   Batch 18,850  of  45,000.    Elapsed: 4:17:27.
#   Batch 18,900  of  45,000.    Elapsed: 4:18:08.
#   Batch 18,950  of  45,000.    Elapsed: 4:18:49.
#   Batch 19,000  of  45,000.    Elapsed: 4:19:30.
#   Batch 19,050  of  45,000.    Elapsed: 4:20:11.
#   Batch 19,100  of  45,000.    Elapsed: 4:20:52.
#   Batch 19,150  of  45,000.    Elapsed: 4:21:33.
#   Batch 19,200  of  45,000.    Elapsed: 4:22:14.
#   Batch 19,250  of  45,000.    Elapsed: 4:22:55.
#   Batch 19,300  of  45,000.    Elapsed: 4:23:36.
#   Batch 19,350  of  45,000.    Elapsed: 4:24:17.
#   Batch 19,400  of  45,000.    Elapsed: 4:24:58.
#   Batch 19,450  of  45,000.    Elapsed: 4:25:39.
#   Batch 19,500  of  45,000.    Elapsed: 4:26:20.
#   Batch 19,550  of  45,000.    Elapsed: 4:27:01.
#   Batch 19,600  of  45,000.    Elapsed: 4:27:43.
#   Batch 19,650  of  45,000.    Elapsed: 4:28:24.
#   Batch 19,700  of  45,000.    Elapsed: 4:29:05.
#   Batch 19,750  of  45,000.    Elapsed: 4:29:46.
#   Batch 19,800  of  45,000.    Elapsed: 4:30:27.
#   Batch 19,850  of  45,000.    Elapsed: 4:31:08.
#   Batch 19,900  of  45,000.    Elapsed: 4:31:49.
#   Batch 19,950  of  45,000.    Elapsed: 4:32:29.
#   Batch 20,000  of  45,000.    Elapsed: 4:33:10.
#   Batch 20,050  of  45,000.    Elapsed: 4:33:51.
#   Batch 20,100  of  45,000.    Elapsed: 4:34:33.
#   Batch 20,150  of  45,000.    Elapsed: 4:35:14.
#   Batch 20,200  of  45,000.    Elapsed: 4:35:55.
#   Batch 20,250  of  45,000.    Elapsed: 4:36:36.
#   Batch 20,300  of  45,000.    Elapsed: 4:37:17.
#   Batch 20,350  of  45,000.    Elapsed: 4:37:58.
#   Batch 20,400  of  45,000.    Elapsed: 4:38:39.
#   Batch 20,450  of  45,000.    Elapsed: 4:39:19.
#   Batch 20,500  of  45,000.    Elapsed: 4:40:00.
#   Batch 20,550  of  45,000.    Elapsed: 4:40:41.
#   Batch 20,600  of  45,000.    Elapsed: 4:41:23.
#   Batch 20,650  of  45,000.    Elapsed: 4:42:04.
#   Batch 20,700  of  45,000.    Elapsed: 4:42:45.
#   Batch 20,750  of  45,000.    Elapsed: 4:43:26.
#   Batch 20,800  of  45,000.    Elapsed: 4:44:06.
#   Batch 20,850  of  45,000.    Elapsed: 4:44:47.
#   Batch 20,900  of  45,000.    Elapsed: 4:45:28.
#   Batch 20,950  of  45,000.    Elapsed: 4:46:09.
#   Batch 21,000  of  45,000.    Elapsed: 4:46:50.
#   Batch 21,050  of  45,000.    Elapsed: 4:47:31.
#   Batch 21,100  of  45,000.    Elapsed: 4:48:12.
#   Batch 21,150  of  45,000.    Elapsed: 4:48:53.
#   Batch 21,200  of  45,000.    Elapsed: 4:49:35.
#   Batch 21,250  of  45,000.    Elapsed: 4:50:16.
#   Batch 21,300  of  45,000.    Elapsed: 4:50:57.
#   Batch 21,350  of  45,000.    Elapsed: 4:51:38.
#   Batch 21,400  of  45,000.    Elapsed: 4:52:19.
#   Batch 21,450  of  45,000.    Elapsed: 4:53:00.
#   Batch 21,500  of  45,000.    Elapsed: 4:53:41.
#   Batch 21,550  of  45,000.    Elapsed: 4:54:22.
#   Batch 21,600  of  45,000.    Elapsed: 4:55:03.
#   Batch 21,650  of  45,000.    Elapsed: 4:55:44.
#   Batch 21,700  of  45,000.    Elapsed: 4:56:25.
#   Batch 21,750  of  45,000.    Elapsed: 4:57:06.
#   Batch 21,800  of  45,000.    Elapsed: 4:57:47.
#   Batch 21,850  of  45,000.    Elapsed: 4:58:28.
#   Batch 21,900  of  45,000.    Elapsed: 4:59:09.
#   Batch 21,950  of  45,000.    Elapsed: 4:59:50.
#   Batch 22,000  of  45,000.    Elapsed: 5:00:30.
#   Batch 22,050  of  45,000.    Elapsed: 5:01:12.
#   Batch 22,100  of  45,000.    Elapsed: 5:01:53.
#   Batch 22,150  of  45,000.    Elapsed: 5:02:34.
#   Batch 22,200  of  45,000.    Elapsed: 5:03:15.
#   Batch 22,250  of  45,000.    Elapsed: 5:03:56.
#   Batch 22,300  of  45,000.    Elapsed: 5:04:37.
#   Batch 22,350  of  45,000.    Elapsed: 5:05:18.
#   Batch 22,400  of  45,000.    Elapsed: 5:05:59.
#   Batch 22,450  of  45,000.    Elapsed: 5:06:40.
#   Batch 22,500  of  45,000.    Elapsed: 5:07:21.
#   Batch 22,550  of  45,000.    Elapsed: 5:08:02.
#   Batch 22,600  of  45,000.    Elapsed: 5:08:43.
#   Batch 22,650  of  45,000.    Elapsed: 5:09:24.
#   Batch 22,700  of  45,000.    Elapsed: 5:10:05.
#   Batch 22,750  of  45,000.    Elapsed: 5:10:46.
#   Batch 22,800  of  45,000.    Elapsed: 5:11:27.
#   Batch 22,850  of  45,000.    Elapsed: 5:12:08.
#   Batch 22,900  of  45,000.    Elapsed: 5:12:49.
#   Batch 22,950  of  45,000.    Elapsed: 5:13:30.
#   Batch 23,000  of  45,000.    Elapsed: 5:14:11.
#   Batch 23,050  of  45,000.    Elapsed: 5:14:52.
#   Batch 23,100  of  45,000.    Elapsed: 5:15:33.
#   Batch 23,150  of  45,000.    Elapsed: 5:16:14.
#   Batch 23,200  of  45,000.    Elapsed: 5:16:55.
#   Batch 23,250  of  45,000.    Elapsed: 5:17:36.
#   Batch 23,300  of  45,000.    Elapsed: 5:18:17.
#   Batch 23,350  of  45,000.    Elapsed: 5:18:58.
#   Batch 23,400  of  45,000.    Elapsed: 5:19:39.
#   Batch 23,450  of  45,000.    Elapsed: 5:20:20.
#   Batch 23,500  of  45,000.    Elapsed: 5:21:01.
#   Batch 23,550  of  45,000.    Elapsed: 5:21:42.
#   Batch 23,600  of  45,000.    Elapsed: 5:22:23.
#   Batch 23,650  of  45,000.    Elapsed: 5:23:04.
#   Batch 23,700  of  45,000.    Elapsed: 5:23:45.
#   Batch 23,750  of  45,000.    Elapsed: 5:24:26.
#   Batch 23,800  of  45,000.    Elapsed: 5:25:06.
#   Batch 23,850  of  45,000.    Elapsed: 5:25:47.
#   Batch 23,900  of  45,000.    Elapsed: 5:26:28.
#   Batch 23,950  of  45,000.    Elapsed: 5:27:09.
#   Batch 24,000  of  45,000.    Elapsed: 5:27:50.
#   Batch 24,050  of  45,000.    Elapsed: 5:28:31.
#   Batch 24,100  of  45,000.    Elapsed: 5:29:12.
#   Batch 24,150  of  45,000.    Elapsed: 5:29:53.
#   Batch 24,200  of  45,000.    Elapsed: 5:30:34.
#   Batch 24,250  of  45,000.    Elapsed: 5:31:15.
#   Batch 24,300  of  45,000.    Elapsed: 5:31:56.
#   Batch 24,350  of  45,000.    Elapsed: 5:32:37.
#   Batch 24,400  of  45,000.    Elapsed: 5:33:18.
#   Batch 24,450  of  45,000.    Elapsed: 5:33:59.
#   Batch 24,500  of  45,000.    Elapsed: 5:34:40.
#   Batch 24,550  of  45,000.    Elapsed: 5:35:20.
#   Batch 24,600  of  45,000.    Elapsed: 5:36:01.
#   Batch 24,650  of  45,000.    Elapsed: 5:36:42.
#   Batch 24,700  of  45,000.    Elapsed: 5:37:24.
#   Batch 24,750  of  45,000.    Elapsed: 5:38:05.
#   Batch 24,800  of  45,000.    Elapsed: 5:38:46.
#   Batch 24,850  of  45,000.    Elapsed: 5:39:27.
#   Batch 24,900  of  45,000.    Elapsed: 5:40:07.
#   Batch 24,950  of  45,000.    Elapsed: 5:40:48.
#   Batch 25,000  of  45,000.    Elapsed: 5:41:29.
#   Batch 25,050  of  45,000.    Elapsed: 5:42:10.
#   Batch 25,100  of  45,000.    Elapsed: 5:42:51.
#   Batch 25,150  of  45,000.    Elapsed: 5:43:32.
#   Batch 25,200  of  45,000.    Elapsed: 5:44:13.
#   Batch 25,250  of  45,000.    Elapsed: 5:44:55.
#   Batch 25,300  of  45,000.    Elapsed: 5:45:35.
#   Batch 25,350  of  45,000.    Elapsed: 5:46:16.
#   Batch 25,400  of  45,000.    Elapsed: 5:46:57.
#   Batch 25,450  of  45,000.    Elapsed: 5:47:38.
#   Batch 25,500  of  45,000.    Elapsed: 5:48:19.
#   Batch 25,550  of  45,000.    Elapsed: 5:49:00.
#   Batch 25,600  of  45,000.    Elapsed: 5:49:41.
#   Batch 25,650  of  45,000.    Elapsed: 5:50:22.
#   Batch 25,700  of  45,000.    Elapsed: 5:51:03.
#   Batch 25,750  of  45,000.    Elapsed: 5:51:44.
#   Batch 25,800  of  45,000.    Elapsed: 5:52:25.
#   Batch 25,850  of  45,000.    Elapsed: 5:53:06.
#   Batch 25,900  of  45,000.    Elapsed: 5:53:48.
#   Batch 25,950  of  45,000.    Elapsed: 5:54:29.
#   Batch 26,000  of  45,000.    Elapsed: 5:55:09.
#   Batch 26,050  of  45,000.    Elapsed: 5:55:50.
#   Batch 26,100  of  45,000.    Elapsed: 5:56:31.
#   Batch 26,150  of  45,000.    Elapsed: 5:57:12.
#   Batch 26,200  of  45,000.    Elapsed: 5:57:53.
#   Batch 26,250  of  45,000.    Elapsed: 5:58:34.
#   Batch 26,300  of  45,000.    Elapsed: 5:59:15.
#   Batch 26,350  of  45,000.    Elapsed: 5:59:56.
#   Batch 26,400  of  45,000.    Elapsed: 6:00:37.
#   Batch 26,450  of  45,000.    Elapsed: 6:01:18.
#   Batch 26,500  of  45,000.    Elapsed: 6:01:59.
#   Batch 26,550  of  45,000.    Elapsed: 6:02:40.
#   Batch 26,600  of  45,000.    Elapsed: 6:03:21.
#   Batch 26,650  of  45,000.    Elapsed: 6:04:02.
#   Batch 26,700  of  45,000.    Elapsed: 6:04:43.
#   Batch 26,750  of  45,000.    Elapsed: 6:05:24.
#   Batch 26,800  of  45,000.    Elapsed: 6:06:05.
#   Batch 26,850  of  45,000.    Elapsed: 6:06:46.
#   Batch 26,900  of  45,000.    Elapsed: 6:07:27.
#   Batch 26,950  of  45,000.    Elapsed: 6:08:08.
#   Batch 27,000  of  45,000.    Elapsed: 6:08:49.
#   Batch 27,050  of  45,000.    Elapsed: 6:09:30.
#   Batch 27,100  of  45,000.    Elapsed: 6:10:11.
#   Batch 27,150  of  45,000.    Elapsed: 6:10:52.
#   Batch 27,200  of  45,000.    Elapsed: 6:11:33.
#   Batch 27,250  of  45,000.    Elapsed: 6:12:14.
#   Batch 27,300  of  45,000.    Elapsed: 6:12:55.
#   Batch 27,350  of  45,000.    Elapsed: 6:13:36.
#   Batch 27,400  of  45,000.    Elapsed: 6:14:17.
#   Batch 27,450  of  45,000.    Elapsed: 6:14:58.
#   Batch 27,500  of  45,000.    Elapsed: 6:15:39.
#   Batch 27,550  of  45,000.    Elapsed: 6:16:20.
#   Batch 27,600  of  45,000.    Elapsed: 6:17:01.
#   Batch 27,650  of  45,000.    Elapsed: 6:17:42.
#   Batch 27,700  of  45,000.    Elapsed: 6:18:23.
#   Batch 27,750  of  45,000.    Elapsed: 6:19:04.
#   Batch 27,800  of  45,000.    Elapsed: 6:19:45.
#   Batch 27,850  of  45,000.    Elapsed: 6:20:26.
#   Batch 27,900  of  45,000.    Elapsed: 6:21:07.
#   Batch 27,950  of  45,000.    Elapsed: 6:21:48.
#   Batch 28,000  of  45,000.    Elapsed: 6:22:29.
#   Batch 28,050  of  45,000.    Elapsed: 6:23:10.
#   Batch 28,100  of  45,000.    Elapsed: 6:23:51.
#   Batch 28,150  of  45,000.    Elapsed: 6:24:32.
#   Batch 28,200  of  45,000.    Elapsed: 6:25:13.
#   Batch 28,250  of  45,000.    Elapsed: 6:25:54.
#   Batch 28,300  of  45,000.    Elapsed: 6:26:35.
#   Batch 28,350  of  45,000.    Elapsed: 6:27:15.
#   Batch 28,400  of  45,000.    Elapsed: 6:27:57.
#   Batch 28,450  of  45,000.    Elapsed: 6:28:38.
#   Batch 28,500  of  45,000.    Elapsed: 6:29:19.
#   Batch 28,550  of  45,000.    Elapsed: 6:30:00.
#   Batch 28,600  of  45,000.    Elapsed: 6:30:41.
#   Batch 28,650  of  45,000.    Elapsed: 6:31:22.
#   Batch 28,700  of  45,000.    Elapsed: 6:32:03.
#   Batch 28,750  of  45,000.    Elapsed: 6:32:44.
#   Batch 28,800  of  45,000.    Elapsed: 6:33:25.
#   Batch 28,850  of  45,000.    Elapsed: 6:34:05.
#   Batch 28,900  of  45,000.    Elapsed: 6:34:46.
#   Batch 28,950  of  45,000.    Elapsed: 6:35:27.
#   Batch 29,000  of  45,000.    Elapsed: 6:36:09.
#   Batch 29,050  of  45,000.    Elapsed: 6:36:50.
#   Batch 29,100  of  45,000.    Elapsed: 6:37:31.
#   Batch 29,150  of  45,000.    Elapsed: 6:38:12.
#   Batch 29,200  of  45,000.    Elapsed: 6:38:53.
#   Batch 29,250  of  45,000.    Elapsed: 6:39:34.
#   Batch 29,300  of  45,000.    Elapsed: 6:40:15.
#   Batch 29,350  of  45,000.    Elapsed: 6:40:56.
#   Batch 29,400  of  45,000.    Elapsed: 6:41:37.
#   Batch 29,450  of  45,000.    Elapsed: 6:42:17.
#   Batch 29,500  of  45,000.    Elapsed: 6:42:58.
#   Batch 29,550  of  45,000.    Elapsed: 6:43:39.
#   Batch 29,600  of  45,000.    Elapsed: 6:44:20.
#   Batch 29,650  of  45,000.    Elapsed: 6:45:02.
#   Batch 29,700  of  45,000.    Elapsed: 6:45:43.
#   Batch 29,750  of  45,000.    Elapsed: 6:46:24.
#   Batch 29,800  of  45,000.    Elapsed: 6:47:05.
#   Batch 29,850  of  45,000.    Elapsed: 6:47:46.
#   Batch 29,900  of  45,000.    Elapsed: 6:48:27.
#   Batch 29,950  of  45,000.    Elapsed: 6:49:08.
#   Batch 30,000  of  45,000.    Elapsed: 6:49:49.
#   Batch 30,050  of  45,000.    Elapsed: 6:50:30.
#   Batch 30,100  of  45,000.    Elapsed: 6:51:11.
#   Batch 30,150  of  45,000.    Elapsed: 6:51:52.
#   Batch 30,200  of  45,000.    Elapsed: 6:52:33.
#   Batch 30,250  of  45,000.    Elapsed: 6:53:14.
#   Batch 30,300  of  45,000.    Elapsed: 6:53:54.
#   Batch 30,350  of  45,000.    Elapsed: 6:54:35.
#   Batch 30,400  of  45,000.    Elapsed: 6:55:16.
#   Batch 30,450  of  45,000.    Elapsed: 6:55:57.
#   Batch 30,500  of  45,000.    Elapsed: 6:56:38.
#   Batch 30,550  of  45,000.    Elapsed: 6:57:20.
#   Batch 30,600  of  45,000.    Elapsed: 6:58:01.
#   Batch 30,650  of  45,000.    Elapsed: 6:58:42.
#   Batch 30,700  of  45,000.    Elapsed: 6:59:23.
#   Batch 30,750  of  45,000.    Elapsed: 7:00:04.
#   Batch 30,800  of  45,000.    Elapsed: 7:00:45.
#   Batch 30,850  of  45,000.    Elapsed: 7:01:26.
#   Batch 30,900  of  45,000.    Elapsed: 7:02:07.
#   Batch 30,950  of  45,000.    Elapsed: 7:02:48.
#   Batch 31,000  of  45,000.    Elapsed: 7:03:29.
#   Batch 31,050  of  45,000.    Elapsed: 7:04:10.
#   Batch 31,100  of  45,000.    Elapsed: 7:04:51.
#   Batch 31,150  of  45,000.    Elapsed: 7:05:32.
#   Batch 31,200  of  45,000.    Elapsed: 7:06:13.
#   Batch 31,250  of  45,000.    Elapsed: 7:06:54.
#   Batch 31,300  of  45,000.    Elapsed: 7:07:35.
#   Batch 31,350  of  45,000.    Elapsed: 7:08:16.
#   Batch 31,400  of  45,000.    Elapsed: 7:08:57.
#   Batch 31,450  of  45,000.    Elapsed: 7:09:38.
#   Batch 31,500  of  45,000.    Elapsed: 7:10:19.
#   Batch 31,550  of  45,000.    Elapsed: 7:11:00.
#   Batch 31,600  of  45,000.    Elapsed: 7:11:41.

# %%
import os

# Saving best-practices: if you use defaults names for the model, you can reload it using from_pretrained()

output_dir = '/content/drive/My Drive/temp_datasets/finetuned_bert_save/'

# Create output directory if needed
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

print("Saving model to %s" % output_dir)

# Save a trained model, configuration and tokenizer using `save_pretrained()`.
# They can then be reloaded using `from_pretrained()`
model_to_save = model.module if hasattr(model, 'module') else model  # Take care of distributed/parallel training
model_to_save.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)

# %%
model.eval()

predictions, true_labels = [], []

for batch in test_dataloader:
    
    batch = tuple(t.long().to(device) for t in batch)
    
    b_input_ids, b_input_mask, b_labels = batch
    
    with torch.no_grad():
        
        outputs = model(b_input_ids, 
                        token_type_ids=None,
                        attention_mask=b_input_mask)
        
    logits = outputs[0]
    
    logits = logits.detach().cpu().numpy()
    label_ids = b_labels.to('cpu').numpy()
    
    predictions.append(logits)
    true_labels.append(label_ids)
